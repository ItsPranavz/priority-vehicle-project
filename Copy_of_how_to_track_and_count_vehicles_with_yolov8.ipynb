# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # YOLOv8 Tracking and Counting
#
# ---
#
# [![YouTube](https://badges.aleen42.com/src/youtube.svg)](https://youtu.be/OS5qI9YBkfk)
# [![Roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/yolov8-tracking-and-counting/)
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/roboflow/notebooks)
#
# Ultralytics YOLOv8 is the latest version of the YOLO (You Only Look Once) object detection and image segmentation model developed by Ultralytics. The YOLOv8 model is designed to be fast, accurate, and easy to use, making it an excellent choice for a wide range of object detection and image segmentation tasks. It can be trained on large datasets and is capable of running on a variety of hardware platforms, from CPUs to GPUs.
#
# ## ⚠️ Disclaimer
#
# This notebook uses legacy versions of ByteTrack and Supervision. To be up to date, use our updated [notebook](https://colab.research.google.com/github/roboflow-ai/notebooks/blob/main/notebooks/how-to-track-and-count-vehicles-with-yolov8-and-supervison.ipynb).
#
# ## Accompanying Blog Post
#
# We recommend that you follow along in this notebook while reading the [blog post](https://blog.roboflow.com/yolov8-tracking-and-counting/) on how to train YOLOv8 Tracking and Counting, concurrently.
#
# ## Pro Tip: Use GPU Acceleration
#
# If you are running this notebook in Google Colab, navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`. This will ensure your notebook uses a GPU, which will significantly speed up model training times.
#
# ## Steps in this Tutorial
#
# In this tutorial, we are going to cover:
#
# - Before you start
# - Download video
# - Install YOLOv8
# - Install ByteTrack
# - Install Roboflow Supervision
# - Tracking utils
# - Load pre-trained YOLOv8 model
# - Predict and annotate single frame
# - Predict and annotate whole video
#
# **Let's begin!**

# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Fri Nov  3 10:05:46 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   63C    P8    13W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Download video

# %%
# %cd {HOME}
#!wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1pz68D1Gsx80MoPg-_q-IbEdESEmyVLm-' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1pz68D1Gsx80MoPg-_q-IbEdESEmyVLm-" -O vehicle-counting.mp4 && rm -rf /tmp/cookies.txt
# Out:
# /content

# %%
SOURCE_VIDEO_PATH = f"{HOME}/vehicle-counting.mp4"

# %% [markdown]
# ## Install YOLOv8
#
# ⚠️ YOLOv8 is still under heavy development. Breaking changes are being introduced almost weekly. We strive to make our YOLOv8 notebooks work with the latest version of the library. Last tests took place on **23.01.2023** with version **YOLOv8.0.17**.
#
# If you notice that our notebook behaves incorrectly - especially if you experience errors that prevent you from going through the tutorial - don't hesitate! Let us know and open an [issue](https://github.com/roboflow/notebooks/issues) on the Roboflow Notebooks repository.

# %%
# Pip install method (recommended)

# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.205 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.4/78.2 GB disk)

# %% [markdown]
# ## Install ByteTrack
#
# [ByteTrack](https://github.com/ifzhang/ByteTrack) is great tracker but a bit poorly packaged. We need to jump through some fire hoops to make it work in tandem with [YOLOv8](https://github.com/ultralytics/ultralytics).

# %%
# %cd {HOME}
# !git clone https://github.com/ifzhang/ByteTrack.git
# %cd {HOME}/ByteTrack

# workaround related to https://github.com/roboflow/notebooks/issues/80
# !sed -i 's/onnx==1.8.1/onnx==1.9.0/g' requirements.txt

# !pip3 install -q -r requirements.txt
# !python3 setup.py -q develop
# !pip install -q cython_bbox
# !pip install -q onemetric
# workaround related to https://github.com/roboflow/notebooks/issues/112 and https://github.com/roboflow/notebooks/issues/106
# !pip install -q loguru lap thop

from IPython import display
display.clear_output()


import sys
sys.path.append(f"{HOME}/ByteTrack")


import yolox
print("yolox.__version__:", yolox.__version__)
# Out:
# yolox.__version__: 0.1.0

# %%
from yolox.tracker.byte_tracker import BYTETracker, STrack
from onemetric.cv.utils.iou import box_iou_batch
from dataclasses import dataclass


@dataclass(frozen=True)
class BYTETrackerArgs:
    track_thresh: float = 0.25
    track_buffer: int = 30
    match_thresh: float = 0.8
    aspect_ratio_thresh: float = 3.0
    min_box_area: float = 1.0
    mot20: bool = False

# %% [markdown]
# ## Install Roboflow Supervision

# %%
# !pip install supervision==0.1.0


from IPython import display
display.clear_output()


import supervision
print("supervision.__version__:", supervision.__version__)
# Out:
# supervision.__version__: 0.1.0

# %%
from supervision.draw.color import ColorPalette
from supervision.geometry.dataclasses import Point
from supervision.video.dataclasses import VideoInfo
from supervision.video.source import get_video_frames_generator
from supervision.video.sink import VideoSink
from supervision.notebook.utils import show_frame_in_notebook
from supervision.tools.detections import Detections, BoxAnnotator
from supervision.tools.line_counter import LineCounter, LineCounterAnnotator

# %% [markdown]
# ## Tracking utils
#
# Unfortunately, we have to manually match the bounding boxes coming from our model with those created by the tracker.

# %%
from typing import List

import numpy as np


# converts Detections into format that can be consumed by match_detections_with_tracks function
def detections2boxes(detections: Detections) -> np.ndarray:
    return np.hstack((
        detections.xyxy,
        detections.confidence[:, np.newaxis]
    ))


# converts List[STrack] into format that can be consumed by match_detections_with_tracks function
def tracks2boxes(tracks: List[STrack]) -> np.ndarray:
    return np.array([
        track.tlbr
        for track
        in tracks
    ], dtype=float)


# matches our bounding boxes with predictions
def match_detections_with_tracks(
    detections: Detections,
    tracks: List[STrack]
) -> Detections:
    if not np.any(detections.xyxy) or len(tracks) == 0:
        return np.empty((0,))

    tracks_boxes = tracks2boxes(tracks=tracks)
    iou = box_iou_batch(tracks_boxes, detections.xyxy)
    track2detection = np.argmax(iou, axis=1)

    tracker_ids = [None] * len(detections)

    for tracker_index, detection_index in enumerate(track2detection):
        if iou[tracker_index, detection_index] != 0:
            tracker_ids[detection_index] = tracks[tracker_index].track_id

    return tracker_ids

# %% [markdown]
# ## Load pre-trained YOLOv8 model

# %%
# settings
MODEL = "yolov8x.pt"

# %%
from ultralytics import YOLO

model = YOLO(MODEL)
model.fuse()
# Out:
# YOLOv8x summary (fused): 268 layers, 68200608 parameters, 0 gradients, 257.8 GFLOPs

# %% [markdown]
# ## Predict and annotate single frame

# %%
# dict maping class_id to class_name
CLASS_NAMES_DICT = model.model.names
# class_ids of interest - car, motorcycle, bus and truck
CLASS_ID = [2, 3, 5, 7]

# %%
# # create frame generator
# generator = get_video_frames_generator(SOURCE_VIDEO_PATH)
# # create instance of BoxAnnotator
# box_annotator = BoxAnnotator(color=ColorPalette(), thickness=4, text_thickness=4, text_scale=2)
# # acquire first video frame
# iterator = iter(generator)
# frame = next(iterator)
# # model prediction on single frame and conversion to supervision Detections
# results = model(frame)
# detections = Detections(
#     xyxy=results[0].boxes.xyxy.cpu().numpy(),
#     confidence=results[0].boxes.conf.cpu().numpy(),
#     class_id=results[0].boxes.cls.cpu().numpy().astype(int)
# )
# # format custom labels
# labels = [
#     f"{CLASS_NAMES_DICT[class_id]} {confidence:0.2f}"
#     for _, confidence, class_id, tracker_id
#     in detections
# ]
# # annotate and display frame
# frame = box_annotator.annotate(frame=frame, detections=detections, labels=labels)

# %matplotlib inline
# show_frame_in_notebook(frame, (16, 16))

import cv2
# create frame generator
generator = get_video_frames_generator(SOURCE_VIDEO_PATH)
# create instance of BoxAnnotator
box_annotator = BoxAnnotator(color=ColorPalette(), thickness=4, text_thickness=4, text_scale=1)
# acquire first video frame
iterator = iter(generator)
frame = next(iterator)
# model prediction on single frame and conversion to supervision Detections
results = model(frame)
detections = Detections(
    xyxy=results[0].boxes.xyxy.cpu().numpy(),
    confidence=results[0].boxes.conf.cpu().numpy(),
    class_id=results[0].boxes.cls.cpu().numpy().astype(int)
)
# format custom labels
labels = [
    f"{CLASS_NAMES_DICT[class_id]} {confidence:0.2f}"
    for _, confidence, class_id, tracker_id
    in detections
]
frame = box_annotator.annotate(frame=frame, detections=detections, labels=labels)

# Count the number of boxes detected
num_boxes_detected = len(detections)

# Display the count on the top left corner
font = cv2.FONT_HERSHEY_SIMPLEX
font_scale = 1
font_thickness = 2
font_color = (255, 255, 255)
count_text = f'Boxes Detected: {num_boxes_detected}'
text_size = cv2.getTextSize(count_text, font, font_scale, font_thickness)[0]
text_x = 10
text_y = text_size[1] + 10

cv2.putText(frame, count_text, (text_x, text_y), font, font_scale, font_color, font_thickness, lineType=cv2.LINE_AA)

# %matplotlib inline
show_frame_in_notebook(frame, (16, 16))
# Out:
# 0: 640x512 9 cars, 2 traffic lights, 58.9ms
# Speed: 3.5ms preprocess, 58.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 512)

# %% [markdown]
# ## Predict and annotate whole video

# %%
# settings
LINE_START = Point(50, 1500)
LINE_END = Point(3840-50, 1500)

TARGET_VIDEO_PATH = f"{HOME}/vehicle-counting-result.mp4"

# %%
VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
# Out:
# VideoInfo(width=1440, height=1800, fps=30, total_frames=307)

# %%
from tqdm.notebook import tqdm
import cv2


# create BYTETracker instance
byte_tracker = BYTETracker(BYTETrackerArgs())
# create VideoInfo instance
video_info = VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
# create frame generator
generator = get_video_frames_generator(SOURCE_VIDEO_PATH)

# create instance of BoxAnnotator and LineCounterAnnotator
box_annotator = BoxAnnotator(color=ColorPalette(), thickness=4, text_thickness=4, text_scale=1)



# open target video file
with VideoSink(TARGET_VIDEO_PATH, video_info) as sink:
    # loop over video frames
    for frame in tqdm(generator, total=video_info.total_frames):
        # model prediction on single frame and conversion to supervision Detections
        results = model(frame)
        detections = Detections(
            xyxy=results[0].boxes.xyxy.cpu().numpy(),
            confidence=results[0].boxes.conf.cpu().numpy(),
            class_id=results[0].boxes.cls.cpu().numpy().astype(int)
        )
        # filtering out detections with unwanted classes
        mask = np.array([class_id in CLASS_ID for class_id in detections.class_id], dtype=bool)
        detections.filter(mask=mask, inplace=True)
        # tracking detections
        tracks = byte_tracker.update(
            output_results=detections2boxes(detections=detections),
            img_info=frame.shape,
            img_size=frame.shape
        )
        tracker_id = match_detections_with_tracks(detections=detections, tracks=tracks)
        detections.tracker_id = np.array(tracker_id)
        # filtering out detections without trackers
        mask = np.array([tracker_id is not None for tracker_id in detections.tracker_id], dtype=bool)
        detections.filter(mask=mask, inplace=True)
        # format custom labels
        labels = [
            f"#{tracker_id} {CLASS_NAMES_DICT[class_id]} {confidence:0.2f}"
            for _, confidence, class_id, tracker_id
            in detections
        ]

        # annotate frame
        frame = box_annotator.annotate(frame=frame, detections=detections, labels=labels)


        # Display box count for this frame
        box_count = len(detections)
        font = cv2.FONT_HERSHEY_SIMPLEX
        font_scale = 1
        font_thickness = 2
        font_color = (255, 255, 255)
        count_text = f'Boxes Detected: {box_count}'
        text_size = cv2.getTextSize(count_text, font, font_scale, font_thickness)[0]
        text_x = 10
        text_y = text_size[1] + 10

        cv2.putText(frame, count_text, (text_x, text_y), font, font_scale, font_color, font_thickness, lineType=cv2.LINE_AA)

        sink.write_frame(frame)
# Out:
#   0%|          | 0/307 [00:00<?, ?it/s]
# 0: 640x512 9 cars, 2 traffic lights, 75.4ms
# Speed: 4.2ms preprocess, 75.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 10 cars, 3 traffic lights, 75.7ms
# Speed: 11.7ms preprocess, 75.7ms inference, 7.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 4 traffic lights, 74.7ms
# Speed: 9.0ms preprocess, 74.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 11 cars, 2 traffic lights, 74.2ms
# Speed: 3.9ms preprocess, 74.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 15 cars, 2 traffic lights, 66.4ms
# Speed: 3.8ms preprocess, 66.4ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 12 cars, 1 traffic light, 58.7ms
# Speed: 3.7ms preprocess, 58.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 3 traffic lights, 53.3ms
# Speed: 5.5ms preprocess, 53.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 5 cars, 4 traffic lights, 53.1ms
# Speed: 3.8ms preprocess, 53.1ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 5 cars, 1 truck, 3 traffic lights, 43.3ms
# Speed: 3.9ms preprocess, 43.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 5 cars, 1 truck, 3 traffic lights, 43.2ms
# Speed: 9.1ms preprocess, 43.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 4 cars, 4 traffic lights, 40.7ms
# Speed: 3.7ms preprocess, 40.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 5 traffic lights, 40.0ms
# Speed: 4.7ms preprocess, 40.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 5 cars, 4 traffic lights, 38.8ms
# Speed: 4.6ms preprocess, 38.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 5 cars, 5 traffic lights, 39.3ms
# Speed: 4.0ms preprocess, 39.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 1 bus, 4 traffic lights, 38.8ms
# Speed: 3.9ms preprocess, 38.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 6 traffic lights, 40.2ms
# Speed: 3.8ms preprocess, 40.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 10 cars, 5 traffic lights, 39.9ms
# Speed: 4.0ms preprocess, 39.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 4 traffic lights, 38.6ms
# Speed: 4.3ms preprocess, 38.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 4 traffic lights, 44.7ms
# Speed: 5.6ms preprocess, 44.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 10 cars, 3 traffic lights, 37.2ms
# Speed: 4.1ms preprocess, 37.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 3 traffic lights, 38.2ms
# Speed: 4.0ms preprocess, 38.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 10 cars, 2 traffic lights, 37.9ms
# Speed: 4.1ms preprocess, 37.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 4 traffic lights, 41.0ms
# Speed: 3.9ms preprocess, 41.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 3 traffic lights, 41.4ms
# Speed: 4.8ms preprocess, 41.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 2 traffic lights, 41.4ms
# Speed: 4.7ms preprocess, 41.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 1 traffic light, 40.9ms
# Speed: 3.9ms preprocess, 40.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 3 traffic lights, 39.5ms
# Speed: 4.3ms preprocess, 39.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 2 traffic lights, 37.2ms
# Speed: 5.6ms preprocess, 37.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 5 traffic lights, 36.4ms
# Speed: 9.3ms preprocess, 36.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 3 traffic lights, 39.2ms
# Speed: 4.0ms preprocess, 39.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 4 cars, 3 traffic lights, 39.8ms
# Speed: 4.5ms preprocess, 39.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 2 traffic lights, 38.8ms
# Speed: 5.2ms preprocess, 38.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 6 traffic lights, 38.6ms
# Speed: 4.8ms preprocess, 38.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 5 cars, 6 traffic lights, 39.4ms
# Speed: 4.8ms preprocess, 39.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 1 bus, 4 traffic lights, 40.1ms
# Speed: 8.9ms preprocess, 40.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 4 traffic lights, 39.1ms
# Speed: 4.2ms preprocess, 39.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 4 cars, 5 traffic lights, 36.5ms
# Speed: 4.8ms preprocess, 36.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 4 traffic lights, 37.5ms
# Speed: 4.8ms preprocess, 37.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 4 cars, 5 traffic lights, 37.9ms
# Speed: 4.5ms preprocess, 37.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 5 traffic lights, 37.8ms
# Speed: 3.9ms preprocess, 37.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 1 bus, 4 traffic lights, 37.7ms
# Speed: 5.0ms preprocess, 37.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 1 bus, 5 traffic lights, 37.6ms
# Speed: 4.7ms preprocess, 37.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 5 traffic lights, 38.6ms
# Speed: 3.8ms preprocess, 38.6ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 1 bus, 4 traffic lights, 38.8ms
# Speed: 4.7ms preprocess, 38.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 3 traffic lights, 40.3ms
# Speed: 12.9ms preprocess, 40.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 4 traffic lights, 38.3ms
# Speed: 4.4ms preprocess, 38.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 5 cars, 4 traffic lights, 38.0ms
# Speed: 3.8ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 4 traffic lights, 37.0ms
# Speed: 5.6ms preprocess, 37.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 4 traffic lights, 36.6ms
# Speed: 4.5ms preprocess, 36.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 4 cars, 5 traffic lights, 37.6ms
# Speed: 3.9ms preprocess, 37.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 3 traffic lights, 40.9ms
# Speed: 4.2ms preprocess, 40.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 2 traffic lights, 40.5ms
# Speed: 4.0ms preprocess, 40.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 2 traffic lights, 40.1ms
# Speed: 3.9ms preprocess, 40.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 5 traffic lights, 40.2ms
# Speed: 5.9ms preprocess, 40.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 3 traffic lights, 38.2ms
# Speed: 5.9ms preprocess, 38.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 2 traffic lights, 36.8ms
# Speed: 4.0ms preprocess, 36.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 5 traffic lights, 38.4ms
# Speed: 5.2ms preprocess, 38.4ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 5 traffic lights, 39.0ms
# Speed: 9.8ms preprocess, 39.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 5 traffic lights, 38.8ms
# Speed: 3.8ms preprocess, 38.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 6 traffic lights, 38.9ms
# Speed: 3.9ms preprocess, 38.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 5 cars, 3 traffic lights, 43.2ms
# Speed: 4.5ms preprocess, 43.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 4 cars, 1 bus, 3 traffic lights, 39.8ms
# Speed: 4.3ms preprocess, 39.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 2 traffic lights, 37.8ms
# Speed: 3.9ms preprocess, 37.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 5 cars, 2 traffic lights, 39.2ms
# Speed: 4.0ms preprocess, 39.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 2 traffic lights, 38.3ms
# Speed: 4.4ms preprocess, 38.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 2 traffic lights, 37.0ms
# Speed: 4.1ms preprocess, 37.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 2 traffic lights, 36.8ms
# Speed: 4.5ms preprocess, 36.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 2 traffic lights, 38.5ms
# Speed: 4.1ms preprocess, 38.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 1 traffic light, 38.1ms
# Speed: 5.9ms preprocess, 38.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 5 cars, 3 traffic lights, 40.5ms
# Speed: 3.8ms preprocess, 40.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 10 cars, 2 traffic lights, 40.0ms
# Speed: 15.1ms preprocess, 40.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 5 cars, 2 traffic lights, 39.8ms
# Speed: 5.5ms preprocess, 39.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 3 traffic lights, 40.0ms
# Speed: 3.6ms preprocess, 40.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 1 traffic light, 38.5ms
# Speed: 4.1ms preprocess, 38.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 12 cars, 3 traffic lights, 39.0ms
# Speed: 3.9ms preprocess, 39.0ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 1 traffic light, 39.9ms
# Speed: 3.6ms preprocess, 39.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 1 truck, 2 traffic lights, 39.9ms
# Speed: 3.8ms preprocess, 39.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 13 cars, 4 traffic lights, 40.2ms
# Speed: 3.9ms preprocess, 40.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 11 cars, 3 traffic lights, 39.0ms
# Speed: 3.6ms preprocess, 39.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 3 traffic lights, 39.4ms
# Speed: 3.6ms preprocess, 39.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 4 traffic lights, 39.2ms
# Speed: 6.4ms preprocess, 39.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 12 cars, 3 traffic lights, 40.3ms
# Speed: 4.5ms preprocess, 40.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 2 traffic lights, 41.0ms
# Speed: 3.8ms preprocess, 41.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 2 traffic lights, 42.7ms
# Speed: 3.8ms preprocess, 42.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 11 cars, 1 traffic light, 42.5ms
# Speed: 9.2ms preprocess, 42.5ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 12 cars, 3 traffic lights, 40.6ms
# Speed: 3.8ms preprocess, 40.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 3 traffic lights, 39.9ms
# Speed: 3.9ms preprocess, 39.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 11 cars, 2 traffic lights, 39.3ms
# Speed: 4.7ms preprocess, 39.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 1 traffic light, 37.0ms
# Speed: 4.9ms preprocess, 37.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 10 cars, 2 traffic lights, 38.4ms
# Speed: 4.1ms preprocess, 38.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 10 cars, 1 traffic light, 39.7ms
# Speed: 4.6ms preprocess, 39.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 12 cars, 3 traffic lights, 41.2ms
# Speed: 6.0ms preprocess, 41.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 15 cars, 5 traffic lights, 39.6ms
# Speed: 4.0ms preprocess, 39.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 3 traffic lights, 36.8ms
# Speed: 3.8ms preprocess, 36.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 4 traffic lights, 38.5ms
# Speed: 5.6ms preprocess, 38.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 3 traffic lights, 39.8ms
# Speed: 3.8ms preprocess, 39.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 3 traffic lights, 38.4ms
# Speed: 3.9ms preprocess, 38.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 12 cars, 1 traffic light, 41.5ms
# Speed: 4.0ms preprocess, 41.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 10 cars, 2 buss, 1 traffic light, 41.7ms
# Speed: 4.6ms preprocess, 41.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 14 cars, 1 bus, 2 traffic lights, 40.9ms
# Speed: 7.1ms preprocess, 40.9ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 15 cars, 2 traffic lights, 37.3ms
# Speed: 4.4ms preprocess, 37.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 2 traffic lights, 39.8ms
# Speed: 5.7ms preprocess, 39.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 1 traffic light, 42.7ms
# Speed: 4.1ms preprocess, 42.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 4 traffic lights, 40.3ms
# Speed: 3.8ms preprocess, 40.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 6 cars, 3 traffic lights, 41.0ms
# Speed: 3.7ms preprocess, 41.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 3 traffic lights, 39.9ms
# Speed: 4.5ms preprocess, 39.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 4 cars, 2 traffic lights, 40.1ms
# Speed: 8.9ms preprocess, 40.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 4 cars, 1 traffic light, 40.3ms
# Speed: 5.0ms preprocess, 40.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 1 traffic light, 39.5ms
# Speed: 4.0ms preprocess, 39.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 38.8ms
# Speed: 4.6ms preprocess, 38.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 1 traffic light, 38.4ms
# Speed: 4.2ms preprocess, 38.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 39.6ms
# Speed: 4.0ms preprocess, 39.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 2 traffic lights, 40.0ms
# Speed: 5.6ms preprocess, 40.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 2 traffic lights, 38.3ms
# Speed: 4.0ms preprocess, 38.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 2 traffic lights, 37.0ms
# Speed: 4.1ms preprocess, 37.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 4 cars, 1 traffic light, 38.0ms
# Speed: 6.3ms preprocess, 38.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 2 traffic lights, 40.3ms
# Speed: 6.9ms preprocess, 40.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 4 cars, 3 traffic lights, 40.7ms
# Speed: 3.8ms preprocess, 40.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 2 traffic lights, 41.3ms
# Speed: 13.0ms preprocess, 41.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 4 traffic lights, 40.5ms
# Speed: 4.2ms preprocess, 40.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 1 traffic light, 50.1ms
# Speed: 4.1ms preprocess, 50.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 2 traffic lights, 42.9ms
# Speed: 4.3ms preprocess, 42.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 4 cars, 2 traffic lights, 42.3ms
# Speed: 5.9ms preprocess, 42.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 3 traffic lights, 42.2ms
# Speed: 4.2ms preprocess, 42.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 4 traffic lights, 42.6ms
# Speed: 4.9ms preprocess, 42.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 13 cars, 2 traffic lights, 42.8ms
# Speed: 3.8ms preprocess, 42.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 13 cars, 5 traffic lights, 42.4ms
# Speed: 4.0ms preprocess, 42.4ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 3 traffic lights, 46.7ms
# Speed: 3.8ms preprocess, 46.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 10 cars, 1 bus, 3 traffic lights, 42.4ms
# Speed: 6.4ms preprocess, 42.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 3 traffic lights, 42.1ms
# Speed: 3.9ms preprocess, 42.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 14 cars, 6 traffic lights, 42.8ms
# Speed: 4.0ms preprocess, 42.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 10 cars, 2 traffic lights, 42.4ms
# Speed: 3.8ms preprocess, 42.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 11 cars, 1 bus, 2 traffic lights, 46.1ms
# Speed: 4.4ms preprocess, 46.1ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 1 traffic light, 47.4ms
# Speed: 13.4ms preprocess, 47.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 10 cars, 2 traffic lights, 42.0ms
# Speed: 8.6ms preprocess, 42.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 1 traffic light, 42.6ms
# Speed: 4.1ms preprocess, 42.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 2 traffic lights, 47.5ms
# Speed: 4.2ms preprocess, 47.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 11 cars, 3 traffic lights, 45.4ms
# Speed: 4.8ms preprocess, 45.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 1 traffic light, 43.0ms
# Speed: 7.2ms preprocess, 43.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 1 traffic light, 44.6ms
# Speed: 6.9ms preprocess, 44.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 3 traffic lights, 46.6ms
# Speed: 4.1ms preprocess, 46.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 2 traffic lights, 42.9ms
# Speed: 4.6ms preprocess, 42.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 12 cars, 1 traffic light, 42.6ms
# Speed: 8.2ms preprocess, 42.6ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 11 cars, 1 traffic light, 43.0ms
# Speed: 5.9ms preprocess, 43.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 1 traffic light, 42.5ms
# Speed: 4.0ms preprocess, 42.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 1 traffic light, 42.6ms
# Speed: 4.0ms preprocess, 42.6ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 1 traffic light, 44.8ms
# Speed: 4.3ms preprocess, 44.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 15 cars, 1 bus, 2 traffic lights, 42.3ms
# Speed: 4.2ms preprocess, 42.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 1 truck, 4 traffic lights, 42.9ms
# Speed: 4.1ms preprocess, 42.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 11 cars, 3 traffic lights, 45.5ms
# Speed: 5.2ms preprocess, 45.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 15 cars, 1 truck, 4 traffic lights, 43.9ms
# Speed: 4.2ms preprocess, 43.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 5 traffic lights, 41.8ms
# Speed: 7.9ms preprocess, 41.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 4 traffic lights, 42.8ms
# Speed: 6.0ms preprocess, 42.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 5 traffic lights, 42.0ms
# Speed: 6.8ms preprocess, 42.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 10 cars, 5 traffic lights, 44.6ms
# Speed: 3.9ms preprocess, 44.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 4 traffic lights, 42.1ms
# Speed: 6.2ms preprocess, 42.1ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 4 cars, 2 traffic lights, 43.1ms
# Speed: 4.0ms preprocess, 43.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 1 truck, 5 traffic lights, 43.5ms
# Speed: 4.5ms preprocess, 43.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 5 traffic lights, 42.1ms
# Speed: 11.0ms preprocess, 42.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 1 truck, 4 traffic lights, 42.1ms
# Speed: 3.8ms preprocess, 42.1ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 1 truck, 3 traffic lights, 42.6ms
# Speed: 6.7ms preprocess, 42.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 5 cars, 3 traffic lights, 42.0ms
# Speed: 8.4ms preprocess, 42.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 4 traffic lights, 42.0ms
# Speed: 4.0ms preprocess, 42.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 5 cars, 4 traffic lights, 41.6ms
# Speed: 3.8ms preprocess, 41.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 3 traffic lights, 38.5ms
# Speed: 5.3ms preprocess, 38.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 5 cars, 38.4ms
# Speed: 5.6ms preprocess, 38.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 38.6ms
# Speed: 4.0ms preprocess, 38.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 1 truck, 1 traffic light, 38.2ms
# Speed: 4.0ms preprocess, 38.2ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 10 cars, 1 traffic light, 38.4ms
# Speed: 8.3ms preprocess, 38.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 1 traffic light, 37.3ms
# Speed: 7.9ms preprocess, 37.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 4 cars, 1 traffic light, 37.6ms
# Speed: 4.3ms preprocess, 37.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 1 truck, 2 traffic lights, 38.6ms
# Speed: 4.5ms preprocess, 38.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 5 cars, 2 trucks, 3 traffic lights, 38.7ms
# Speed: 4.8ms preprocess, 38.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 5 cars, 1 truck, 3 traffic lights, 38.2ms
# Speed: 9.9ms preprocess, 38.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 2 traffic lights, 39.2ms
# Speed: 4.0ms preprocess, 39.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 11 cars, 4 traffic lights, 39.0ms
# Speed: 6.1ms preprocess, 39.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 4 traffic lights, 36.7ms
# Speed: 3.8ms preprocess, 36.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 5 cars, 1 truck, 3 traffic lights, 38.2ms
# Speed: 3.9ms preprocess, 38.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 4 cars, 1 truck, 3 traffic lights, 40.0ms
# Speed: 4.2ms preprocess, 40.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 3 traffic lights, 38.3ms
# Speed: 6.2ms preprocess, 38.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 3 traffic lights, 41.4ms
# Speed: 4.4ms preprocess, 41.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 10 cars, 1 traffic light, 41.0ms
# Speed: 3.9ms preprocess, 41.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 4 traffic lights, 41.0ms
# Speed: 3.9ms preprocess, 41.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 1 truck, 4 traffic lights, 36.0ms
# Speed: 4.2ms preprocess, 36.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 15 cars, 1 truck, 4 traffic lights, 38.1ms
# Speed: 3.9ms preprocess, 38.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 1 truck, 5 traffic lights, 38.3ms
# Speed: 5.4ms preprocess, 38.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 10 cars, 1 truck, 4 traffic lights, 39.3ms
# Speed: 3.8ms preprocess, 39.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 1 truck, 4 traffic lights, 38.3ms
# Speed: 7.2ms preprocess, 38.3ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 12 cars, 1 truck, 4 traffic lights, 38.7ms
# Speed: 4.8ms preprocess, 38.7ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 14 cars, 1 bus, 2 trucks, 4 traffic lights, 36.8ms
# Speed: 4.3ms preprocess, 36.8ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 10 cars, 1 truck, 5 traffic lights, 38.0ms
# Speed: 5.1ms preprocess, 38.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 11 cars, 1 truck, 5 traffic lights, 36.5ms
# Speed: 11.0ms preprocess, 36.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 1 truck, 4 traffic lights, 37.6ms
# Speed: 3.9ms preprocess, 37.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 10 cars, 1 truck, 3 traffic lights, 38.7ms
# Speed: 3.8ms preprocess, 38.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 1 truck, 4 traffic lights, 41.0ms
# Speed: 4.2ms preprocess, 41.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 1 truck, 4 traffic lights, 41.0ms
# Speed: 3.7ms preprocess, 41.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 10 cars, 1 truck, 4 traffic lights, 40.8ms
# Speed: 7.5ms preprocess, 40.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 2 trucks, 3 traffic lights, 39.2ms
# Speed: 4.0ms preprocess, 39.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 10 cars, 2 trucks, 4 traffic lights, 37.9ms
# Speed: 3.9ms preprocess, 37.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 1 truck, 2 traffic lights, 40.3ms
# Speed: 4.2ms preprocess, 40.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 3 traffic lights, 39.9ms
# Speed: 7.0ms preprocess, 39.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 13 cars, 2 trucks, 1 traffic light, 41.6ms
# Speed: 3.8ms preprocess, 41.6ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 2 trucks, 2 traffic lights, 42.5ms
# Speed: 3.8ms preprocess, 42.5ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 11 cars, 2 trucks, 2 traffic lights, 41.8ms
# Speed: 11.9ms preprocess, 41.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 11 cars, 1 truck, 2 traffic lights, 42.1ms
# Speed: 5.5ms preprocess, 42.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 1 truck, 1 traffic light, 42.0ms
# Speed: 4.1ms preprocess, 42.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 12 cars, 1 truck, 1 traffic light, 37.5ms
# Speed: 5.7ms preprocess, 37.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 11 cars, 1 truck, 1 traffic light, 38.1ms
# Speed: 6.6ms preprocess, 38.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 12 cars, 1 truck, 1 traffic light, 41.5ms
# Speed: 3.8ms preprocess, 41.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 12 cars, 1 truck, 3 traffic lights, 1 kite, 40.5ms
# Speed: 4.2ms preprocess, 40.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 12 cars, 1 truck, 4 traffic lights, 43.6ms
# Speed: 5.1ms preprocess, 43.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 13 cars, 1 truck, 2 traffic lights, 47.3ms
# Speed: 3.9ms preprocess, 47.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 13 cars, 2 trucks, 3 traffic lights, 42.7ms
# Speed: 4.0ms preprocess, 42.7ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 1 truck, 2 traffic lights, 43.0ms
# Speed: 4.9ms preprocess, 43.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 8 cars, 1 truck, 2 traffic lights, 40.2ms
# Speed: 3.8ms preprocess, 40.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 2 traffic lights, 37.3ms
# Speed: 4.3ms preprocess, 37.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 2 trucks, 3 traffic lights, 38.0ms
# Speed: 4.1ms preprocess, 38.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 2 trucks, 2 traffic lights, 37.8ms
# Speed: 4.0ms preprocess, 37.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 1 truck, 4 traffic lights, 37.7ms
# Speed: 4.9ms preprocess, 37.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 12 cars, 1 truck, 3 traffic lights, 38.7ms
# Speed: 3.0ms preprocess, 38.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 9 cars, 1 truck, 2 traffic lights, 39.2ms
# Speed: 3.9ms preprocess, 39.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 12 cars, 2 trucks, 3 traffic lights, 37.5ms
# Speed: 4.0ms preprocess, 37.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 11 cars, 2 trucks, 2 traffic lights, 38.4ms
# Speed: 4.2ms preprocess, 38.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 1 truck, 3 traffic lights, 37.7ms
# Speed: 7.1ms preprocess, 37.7ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 2 buss, 1 truck, 1 traffic light, 37.0ms
# Speed: 4.0ms preprocess, 37.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 1 bus, 1 truck, 2 traffic lights, 38.6ms
# Speed: 3.7ms preprocess, 38.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 1 bus, 1 truck, 3 traffic lights, 42.5ms
# Speed: 5.4ms preprocess, 42.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 10 cars, 2 trucks, 3 traffic lights, 43.6ms
# Speed: 7.5ms preprocess, 43.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 2 trucks, 3 traffic lights, 42.6ms
# Speed: 3.9ms preprocess, 42.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 10 cars, 2 trucks, 2 traffic lights, 43.8ms
# Speed: 9.4ms preprocess, 43.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 2 trucks, 2 traffic lights, 42.9ms
# Speed: 4.6ms preprocess, 42.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 10 cars, 2 trucks, 1 traffic light, 42.2ms
# Speed: 4.0ms preprocess, 42.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 14 cars, 2 trucks, 2 traffic lights, 40.8ms
# Speed: 4.1ms preprocess, 40.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 2 trucks, 2 traffic lights, 39.0ms
# Speed: 8.7ms preprocess, 39.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 10 cars, 1 truck, 1 traffic light, 36.4ms
# Speed: 3.9ms preprocess, 36.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 1 traffic light, 38.1ms
# Speed: 3.8ms preprocess, 38.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 1 bus, 1 truck, 2 traffic lights, 39.6ms
# Speed: 4.2ms preprocess, 39.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 1 traffic light, 39.4ms
# Speed: 3.8ms preprocess, 39.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 1 bus, 1 truck, 2 traffic lights, 38.7ms
# Speed: 4.3ms preprocess, 38.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 10 cars, 1 bus, 3 traffic lights, 37.3ms
# Speed: 3.6ms preprocess, 37.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 15 cars, 1 bus, 4 traffic lights, 37.4ms
# Speed: 7.5ms preprocess, 37.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 1 bus, 2 traffic lights, 37.5ms
# Speed: 4.2ms preprocess, 37.5ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 4 traffic lights, 38.0ms
# Speed: 4.6ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 4 traffic lights, 39.0ms
# Speed: 5.6ms preprocess, 39.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 1 bus, 4 traffic lights, 39.5ms
# Speed: 3.9ms preprocess, 39.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 4 traffic lights, 40.7ms
# Speed: 3.8ms preprocess, 40.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 5 traffic lights, 41.2ms
# Speed: 9.9ms preprocess, 41.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 5 traffic lights, 41.5ms
# Speed: 3.9ms preprocess, 41.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 2 traffic lights, 41.4ms
# Speed: 3.8ms preprocess, 41.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 14 cars, 1 truck, 2 traffic lights, 37.3ms
# Speed: 6.9ms preprocess, 37.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 1 truck, 1 traffic light, 38.3ms
# Speed: 5.6ms preprocess, 38.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 1 truck, 3 traffic lights, 41.2ms
# Speed: 6.0ms preprocess, 41.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 10 cars, 3 traffic lights, 40.1ms
# Speed: 3.7ms preprocess, 40.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 3 traffic lights, 42.4ms
# Speed: 4.0ms preprocess, 42.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 11 cars, 3 traffic lights, 42.9ms
# Speed: 3.9ms preprocess, 42.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 3 traffic lights, 40.6ms
# Speed: 6.2ms preprocess, 40.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 1 truck, 3 traffic lights, 40.4ms
# Speed: 3.9ms preprocess, 40.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 2 traffic lights, 39.2ms
# Speed: 6.9ms preprocess, 39.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 2 traffic lights, 39.5ms
# Speed: 8.5ms preprocess, 39.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 11 cars, 2 traffic lights, 37.2ms
# Speed: 9.0ms preprocess, 37.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 10 cars, 1 traffic light, 37.5ms
# Speed: 3.8ms preprocess, 37.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 2 traffic lights, 37.0ms
# Speed: 4.0ms preprocess, 37.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 2 traffic lights, 38.2ms
# Speed: 4.5ms preprocess, 38.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 4 cars, 2 traffic lights, 37.7ms
# Speed: 4.0ms preprocess, 37.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 2 traffic lights, 38.8ms
# Speed: 5.7ms preprocess, 38.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 11 cars, 2 traffic lights, 37.5ms
# Speed: 3.9ms preprocess, 37.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 5 cars, 1 bus, 2 traffic lights, 38.9ms
# Speed: 3.9ms preprocess, 38.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 5 cars, 1 bus, 2 traffic lights, 40.5ms
# Speed: 6.4ms preprocess, 40.5ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 1 bus, 1 truck, 2 traffic lights, 39.3ms
# Speed: 4.6ms preprocess, 39.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 10 cars, 1 truck, 3 traffic lights, 40.1ms
# Speed: 3.9ms preprocess, 40.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 13 cars, 1 truck, 3 traffic lights, 40.1ms
# Speed: 4.4ms preprocess, 40.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 11 cars, 1 truck, 3 traffic lights, 39.6ms
# Speed: 9.1ms preprocess, 39.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 11 cars, 1 bus, 3 traffic lights, 39.9ms
# Speed: 5.2ms preprocess, 39.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 1 bus, 1 truck, 4 traffic lights, 39.3ms
# Speed: 4.2ms preprocess, 39.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 16 cars, 1 bus, 1 truck, 3 traffic lights, 37.4ms
# Speed: 7.3ms preprocess, 37.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 1 bus, 1 truck, 2 traffic lights, 36.3ms
# Speed: 8.9ms preprocess, 36.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 1 bus, 1 truck, 3 traffic lights, 38.7ms
# Speed: 4.1ms preprocess, 38.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 4 cars, 1 bus, 3 traffic lights, 38.2ms
# Speed: 10.6ms preprocess, 38.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 1 bus, 3 traffic lights, 38.4ms
# Speed: 3.7ms preprocess, 38.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 1 bus, 3 traffic lights, 38.0ms
# Speed: 4.0ms preprocess, 38.0ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 1 bus, 2 traffic lights, 37.6ms
# Speed: 3.8ms preprocess, 37.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 1 bus, 2 traffic lights, 40.6ms
# Speed: 3.6ms preprocess, 40.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 1 bus, 1 truck, 2 traffic lights, 36.7ms
# Speed: 4.1ms preprocess, 36.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 5 cars, 1 bus, 1 truck, 2 traffic lights, 37.2ms
# Speed: 7.5ms preprocess, 37.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 2 buss, 2 traffic lights, 37.7ms
# Speed: 3.9ms preprocess, 37.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 1 bus, 1 truck, 2 traffic lights, 37.4ms
# Speed: 5.6ms preprocess, 37.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 9 cars, 2 buss, 1 truck, 2 traffic lights, 37.9ms
# Speed: 4.0ms preprocess, 37.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 2 buss, 1 truck, 2 traffic lights, 37.9ms
# Speed: 3.9ms preprocess, 37.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 1 bus, 2 traffic lights, 36.6ms
# Speed: 7.1ms preprocess, 36.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 1 bus, 3 traffic lights, 38.7ms
# Speed: 4.1ms preprocess, 38.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 1 bus, 3 traffic lights, 36.3ms
# Speed: 4.1ms preprocess, 36.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 2 traffic lights, 43.3ms
# Speed: 7.2ms preprocess, 43.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 2 buss, 3 traffic lights, 41.7ms
# Speed: 6.3ms preprocess, 41.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 1 bus, 2 traffic lights, 42.4ms
# Speed: 4.0ms preprocess, 42.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 1 bus, 1 traffic light, 41.7ms
# Speed: 4.1ms preprocess, 41.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 1 bus, 2 traffic lights, 42.6ms
# Speed: 5.5ms preprocess, 42.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 1 bus, 3 traffic lights, 41.8ms
# Speed: 4.1ms preprocess, 41.8ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 4 cars, 1 bus, 1 truck, 2 traffic lights, 43.7ms
# Speed: 3.9ms preprocess, 43.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 5 cars, 1 bus, 1 truck, 3 traffic lights, 43.5ms
# Speed: 3.9ms preprocess, 43.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 4 cars, 1 bus, 1 truck, 3 traffic lights, 44.4ms
# Speed: 6.8ms preprocess, 44.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 1 bus, 1 traffic light, 42.6ms
# Speed: 6.2ms preprocess, 42.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 1 bus, 1 truck, 3 traffic lights, 45.2ms
# Speed: 4.0ms preprocess, 45.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 5 cars, 1 bus, 3 traffic lights, 42.2ms
# Speed: 6.6ms preprocess, 42.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 4 cars, 1 bus, 3 traffic lights, 42.3ms
# Speed: 13.6ms preprocess, 42.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 8 cars, 1 bus, 1 traffic light, 42.7ms
# Speed: 3.9ms preprocess, 42.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 6 cars, 1 truck, 2 traffic lights, 42.7ms
# Speed: 4.1ms preprocess, 42.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 7 cars, 1 truck, 2 traffic lights, 41.1ms
# Speed: 3.8ms preprocess, 41.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)

# %% [markdown]
# ## 🏆 Congratulations
#
# ### Learning Resources
#
# Roboflow has produced many resources that you may find interesting as you advance your knowledge of computer vision:
#
# - [Roboflow Notebooks](https://github.com/roboflow/notebooks): A repository of over 20 notebooks that walk through how to train custom models with a range of model types, from YOLOv7 to SegFormer.
# - [Roboflow YouTube](https://www.youtube.com/c/Roboflow): Our library of videos featuring deep dives into the latest in computer vision, detailed tutorials that accompany our notebooks, and more.
# - [Roboflow Discuss](https://discuss.roboflow.com/): Have a question about how to do something on Roboflow? Ask your question on our discussion forum.
# - [Roboflow Models](https://roboflow.com): Learn about state-of-the-art models and their performance. Find links and tutorials to guide your learning.
#
# ### Convert data formats
#
# Roboflow provides free utilities to convert data between dozens of popular computer vision formats. Check out [Roboflow Formats](https://roboflow.com/formats) to find tutorials on how to convert data between formats in a few clicks.
#
# ### Connect computer vision to your project logic
#
# [Roboflow Templates](https://roboflow.com/templates) is a public gallery of code snippets that you can use to connect computer vision to your project logic. Code snippets range from sending emails after inference to measuring object distance between detections.
